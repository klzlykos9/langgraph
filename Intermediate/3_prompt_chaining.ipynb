# %%
from langgraph.graph import StateGraph, START, END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model = 'gemini-2.5-pro')

# %%
class BlogState(TypedDict):

    title: str
    outline : str
    content : str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']
    # call llm gen outline
    prompt = f'Generate an detailed outline for a blog on an topic -{title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on the title -{title} using the following outline \n {outline} '

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph .add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# add edges 

graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow  = graph.compile()

# %%
initial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(initial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Of course! Here is a detailed outline for a blog post on the "Rise of AI in India." This structure is designed to be comprehensive, engaging, and easy for a writer to follow, complete with suggested content, potential case studies, and SEO elements.\n\n---\n\n### **Blog Post Outline: The AI Revolution: How India is Building its Silicon Satta**\n\n**Target Audience:** Tech enthusiasts, business leaders, policymakers, students, and the global community interested in India\'s growth story.\n\n**Blog Goal:** To provide a comprehensive overview of the drivers, applications, challenges, and future of Artificial Intelligence in India, positioning the nation as a key player on the global AI stage.\n\n**SEO Keywords:**\n*   **Primary:** Rise of AI in India, AI in India, India AI Mission\n*   **Secondary:** AI startups in India, Future of AI in India, AI applications in agriculture, AI in Indian healthcare, Generative AI India, India AI policy\n\n---\n\n### **1. Title (Choose one or create a variation)**\n\n*   The AI Revolution: How India is Scripting its Tech Future\n*   Decoding India\'s AI Ascent: From Back Office to Global Powerhouse\n*   India\'s AI Boom: The Perfect Storm of Data, Talent, and Ambition\n*   Silicon Satta: Why India is the World\'s Next Big Bet in Artificial intelligence\n\n---\n\n### **2. Introduction: The Dawn of a New Era**\n\n*   **Hook:** Start with a powerful, relatable image or statistic.\n    *   *Example:* "From a farmer in rural Maharashtra getting real-time crop advice on his phone, to a doctor in Delhi detecting diabetic retinopathy from a retinal scan in seconds – artificial intelligence is no longer a futuristic concept in India. It\'s here, and it\'s transforming the nation from the ground up."\n*   **Thesis Statement:** Clearly state the blog\'s purpose.\n    *   *Example:* "This article explores the multifaceted rise of AI in India, examining the unique confluence of factors driving its adoption, the groundbreaking applications across key sectors, the challenges that lie ahead, and why India is poised to become a global leader in the AI-driven world."\n*   **Roadmap:** Briefly outline what the reader will learn.\n    *   "We\'ll dive into the \'why now,\' explore real-world case studies, meet the key players, and look towards the future of \'Made in India\' AI."\n\n---\n\n### **3. Section 1: The Perfect Storm – Key Drivers of India\'s AI Boom**\n\n*   **Subtitle:** *Why India, Why Now?*\n*   **A. The Data Dividend:**\n    *   Explain how India became one of the world\'s largest data-generating nations.\n    *   **Key Points:** The Jio effect (ultra-cheap mobile data), massive smartphone penetration, and the digitization of daily life (UPI, Aadhaar).\n    *   **Analogy:** Data is the new oil, and India is one of the world\'s richest reserves.\n*   **B. The Talent Tsunami:**\n    *   Highlight India\'s human capital advantage.\n    *   **Key Points:** World\'s largest population of STEM graduates, premier institutions (IITs, IISc, IIITs), and a growing focus on upskilling and AI-specific education.\n    *   **Statistic:** Mention the number of engineers India produces annually or its ranking in AI skill penetration (e.g., via NASSCOM or LinkedIn reports).\n*   **C. Government as a Catalyst:**\n    *   Discuss the proactive role of government policy.\n    *   **Key Points:** The **National Strategy for AI (#AIforAll)**, the establishment of the **IndiaAI Mission**, and initiatives like Digital India that create the foundational infrastructure for AI deployment.\n*   **D. A Thriving Ecosystem:**\n    *   Talk about the business environment.\n    *   **Key Points:** The world\'s third-largest startup ecosystem, massive inflow of VC funding into AI startups, and the presence of Global Capability Centers (GCCs) of major tech giants (Google, Microsoft, Amazon) doing cutting-edge AI research in India.\n\n---\n\n### **4. Section 2: AI in Action – Transforming the  ...

# %%
print(final_state['outline'])
# Out:
# Of course! Here is a detailed outline for a blog post on the "Rise of AI in India." This structure is designed to be comprehensive, engaging, and easy for a writer to follow, complete with suggested content, potential case studies, and SEO elements.
#
# ---
#
# ### **Blog Post Outline: The AI Revolution: How India is Building its Silicon Satta**
#
# **Target Audience:** Tech enthusiasts, business leaders, policymakers, students, and the global community interested in India's growth story.
#
# **Blog Goal:** To provide a comprehensive overview of the drivers, applications, challenges, and future of Artificial Intelligence in India, positioning the nation as a key player on the global AI stage.
#
# **SEO Keywords:**
# *   **Primary:** Rise of AI in India, AI in India, India AI Mission
# *   **Secondary:** AI startups in India, Future of AI in India, AI applications in agriculture, AI in Indian healthcare, Generative AI India, India AI policy
#
# ---
#
# ### **1. Title (Choose one or create a variation)**
#
# *   The AI Revolution: How India is Scripting its Tech Future
# *   Decoding India's AI Ascent: From Back Office to Global Powerhouse
# *   India's AI Boom: The Perfect Storm of Data, Talent, and Ambition
# *   Silicon Satta: Why India is the World's Next Big Bet in Artificial intelligence
#
# ---
#
# ### **2. Introduction: The Dawn of a New Era**
#
# *   **Hook:** Start with a powerful, relatable image or statistic.
#     *   *Example:* "From a farmer in rural Maharashtra getting real-time crop advice on his phone, to a doctor in Delhi detecting diabetic retinopathy from a retinal scan in seconds – artificial intelligence is no longer a futuristic concept in India. It's here, and it's transforming the nation from the ground up."
# *   **Thesis Statement:** Clearly state the blog's purpose.
#     *   *Example:* "This article explores the multifaceted rise of AI in India, examining the unique confluence of factors driving its adoption, the groundbreaking applications across key sectors, the challenges that lie ahead, and why India is poised to become a global leader in the AI-driven world."
# *   **Roadmap:** Briefly outline what the reader will learn.
#     *   "We'll dive into the 'why now,' explore real-world case studies, meet the key players, and look towards the future of 'Made in India' AI."
#
# ---
#
# ### **3. Section 1: The Perfect Storm – Key Drivers of India's AI Boom**
#
# *   **Subtitle:** *Why India, Why Now?*
# *   **A. The Data Dividend:**
#     *   Explain how India became one of the world's largest data-generating nations.
#     *   **Key Points:** The Jio effect (ultra-cheap mobile data), massive smartphone penetration, and the digitization of daily life (UPI, Aadhaar).
#     *   **Analogy:** Data is the new oil, and India is one of the world's richest reserves.
# *   **B. The Talent Tsunami:**
#     *   Highlight India's human capital advantage.
#     *   **Key Points:** World's largest population of STEM graduates, premier institutions (IITs, IISc, IIITs), and a growing focus on upskilling and AI-specific education.
#     *   **Statistic:** Mention the number of engineers India produces annually or its ranking in AI skill penetration (e.g., via NASSCOM or LinkedIn reports).
# *   **C. Government as a Catalyst:**
#     *   Discuss the proactive role of government policy.
#     *   **Key Points:** The **National Strategy for AI (#AIforAll)**, the establishment of the **IndiaAI Mission**, and initiatives like Digital India that create the foundational infrastructure for AI deployment.
# *   **D. A Thriving Ecosystem:**
#     *   Talk about the business environment.
#     *   **Key Points:** The world's third-largest startup ecosystem, massive inflow of VC funding into AI startups, and the presence of Global Capability Centers (GCCs) of major tech giants (Google, Microsoft, Amazon) doing cutting-edge AI research in India.
#
# ---
#
# ### **4. Section 2: AI in Action – Transforming the Fabric of India**
#
# *   **Subtitle:** *From Code to Reality: Where AI is Making a Difference*
# *   **(Use a case-study or example-driven approach for each sector)**
# *   **A. Healthcare: For a Billion-Strong Nation**
#     *   **Problem:** Doctor-patient ratio, access to diagnostics in rural areas.
#     *   **AI Solution:** AI-powered diagnostic tools (e.g., Niramai for breast cancer screening, Aravind Eye Care for diabetic retinopathy), predictive analytics for disease outbreaks, and personalized medicine.
# *   **B. Agriculture: Sowing the Seeds of the Future**
#     *   **Problem:** Unpredictable weather, low crop yield, inefficient supply chains.
#     *   **AI Solution:** Precision farming using drones and satellite imagery, AI-based soil health monitoring, price prediction models for farmers, and quality sorting of produce.
#     *   **Case Study:** Mention a startup like CropIn or Fasal.
# *   **C. FinTech & Financial Inclusion:**
#     *   **Problem:** Access to credit for the unbanked, fraud detection.
#     *   **AI Solution:** AI algorithms for credit scoring using alternative data, UPI-based fraud detection systems, algorithmic trading, and personalized financial advisory chatbots.
# *   **D. E-commerce & Retail:**
#     *   **Problem:** Hyper-competitive market, complex logistics.
#     *   **AI Solution:** Hyper-personalization engines (Flipkart, Myntra), supply chain optimization, AI-powered chatbots for customer service, and demand forecasting.
# *   **E. Language & Inclusivity (The 'Bharat' Opportunity):**
#     *   **Problem:** Vast linguistic diversity.
#     *   **AI Solution:** Development of Natural Language Processing (NLP) models for Indian languages (e.g., Bhashini project), voice-based services for low-literacy users, and real-time translation.
#
# ---
#
# ### **5. Section 3: Navigating the Hurdles – Challenges on the Road Ahead**
#
# *   **Subtitle:** *The Reality Check for India's AI Ambition*
# *   **A. The Infrastructure and Digital Divide:** While data is cheap, consistent high-speed internet and computational power are not universally accessible.
# *   **B. Data Privacy and Security:** The need for a robust data protection framework (mention the Digital Personal Data Protection Act) to build trust.
# *   **C. Ethical AI and Algorithmic Bias:** Ensuring AI models are not trained on biased data that could perpetuate existing social inequalities (caste, gender, religion).
# *   **D. The Skilling Gap:** The challenge is not just creating STEM grads, but upskilling the existing workforce and creating a large pool of specialized AI/ML experts.
# *   **E. Job Displacement vs. Job Creation:** Address the public fear of AI taking jobs while highlighting the potential for new, higher-value roles to be created.
#
# ---
#
# ### **6. Section 4: The Road to 2030 – What's Next for AI in India?**
#
# *   **Subtitle:** *India's AI Endgame: From Follower to Leader*
# *   **A. The Rise of Generative AI:** How Indian companies and startups are leveraging GenAI for everything from content creation in regional languages to code generation.
# *   **B. India as a "Global AI Hub":** The potential for India to become a hub for "AI for Good," developing frugal, scalable AI solutions for the developing world.
# *   **C. Sovereign AI Capabilities:** The push to build indigenous Large Language Models (LLMs) and compute infrastructure to reduce dependency on foreign tech.
# *   **D. Policy and Regulation:** The future will be shaped by agile, forward-thinking regulations that foster innovation while mitigating risks.
#
# ---
#
# ### **7. Conclusion: The Algorithm of a New India**
#
# *   **Summarize Key Takeaways:** Briefly recap the core message – India's AI rise is a unique story fueled by its demographic, digital, and democratic strengths.
# *   **Final, Inspiring Thought:** Frame AI not just as a technological tool, but as a means to achieve national goals – economic growth, social inclusion, and global leadership.
#     *   *Example:* "The rise of AI in India is more than just a technological trend; it's the algorithm of a new, self-reliant, and ambitious nation. The journey is complex and challenging, but the code for a brighter future is being written today, in labs and farms, cities and villages, across the subcontinent."
# *   **Call to Action (CTA):**
#     *   "What do you think is the most exciting application of AI in India? Share your thoughts in the comments below!"
#     *   "Follow us on [Social Media Links] for more insights into India's tech story."
#
# ---
#
# ### **Visuals and Media to Embed:**
#
# *   **Infographic:** "The 4 Pillars of India's AI Growth" (Data, Talent, Government, Ecosystem).
# *   **Chart:** Growth of internet users or digital payments in India.
# *   **Embedded Video:** A short clip of an Indian AI startup's product in action or a statement from a key government official.
# *   **Pull Quotes:** Use bold, visually distinct quotes from experts or key sections of the article.

# %%
print(final_state['content'])
# Out:
# Of course! Here is a detailed blog post written based on the provided outline.
#
# ---
#
# ## Silicon Satta: Why India is the World's Next Big Bet in Artificial Intelligence
#
# From a farmer in rural Maharashtra getting real-time crop advice on his phone, to a doctor in Delhi detecting diabetic retinopathy from a retinal scan in seconds – artificial intelligence is no longer a futuristic concept in India. It's here, and it's transforming the nation from the ground up. The silent hum of algorithms is becoming the heartbeat of a new, ambitious India.
#
# This article explores the multifaceted **rise of AI in India**, examining the unique confluence of factors driving its adoption, the groundbreaking applications across key sectors, the challenges that lie ahead, and why the nation is poised to become a global leader in the AI-driven world. We'll dive into the 'why now,' explore real-world case studies, meet the key players, and look towards the future of 'Made in India' AI.
#
# ***
#
# ### The Perfect Storm: Key Drivers of India's AI Boom
#
# *Why India, Why Now?* Four powerful forces have converged to create the perfect environment for an AI revolution.
#
# ***[Infographic: The 4 Pillars of India's AI Growth - Data, Talent, Government, and Ecosystem]***
#
# #### A. The Data Dividend
# Data is the new oil, and India is one of the world's richest reserves. The "Jio effect" in 2016 unleashed a tidal wave of affordable mobile data, catapulting hundreds of millions of Indians online. Today, with over 800 million internet users and massive smartphone penetration, India is one of the largest data-generating nations on the planet. This digital lifeblood is further enriched by foundational platforms like the AADHAAR identity system and the Unified Payments Interface (UPI), which digitize transactions and services at an unprecedented scale. This massive, diverse dataset is the fuel that powers hungry AI models.
#
# #### B. The Talent Tsunami
# India's greatest asset has always been its human capital. With the world's largest youth population and one of the highest numbers of STEM graduates annually, the raw talent is immense. Premier institutions like the IITs, IISc, and IIITs have become crucibles for tech innovation. More importantly, there is a palpable hunger for upskilling. A recent NASSCOM report highlighted India's high ranking in AI skill penetration, showcasing a workforce that is rapidly adapting to the demands of the future.
#
# #### C. Government as a Catalyst
# The Indian government has moved from being a spectator to an active catalyst. The **National Strategy for AI (#AIforAll)** laid out a clear vision to leverage AI for inclusive growth. This has been supercharged by the landmark **IndiaAI Mission**, a multi-billion dollar initiative focused on building domestic compute infrastructure, creating large datasets, and fostering a vibrant AI ecosystem. Initiatives like Digital India have already created the digital highways necessary for AI to travel to the remotest corners of the country.
#
# #### D. A Thriving Ecosystem
# India is home to the world's third-largest startup ecosystem, and AI is at its epicentre. A surge of venture capital is flowing into innovative **AI startups in India**, solving uniquely Indian problems. Simultaneously, the Global Capability Centers (GCCs) of tech giants like Google, Microsoft, and Amazon are not just back-offices anymore; they are conducting cutting-edge AI research and development right here in India, creating a symbiotic relationship between local talent and global innovation.
#
# ***
#
# ### AI in Action: Transforming the Fabric of India
#
# *From Code to Reality: Where AI is Making a Difference*
#
# AI in India isn't just a theoretical concept; it's delivering tangible results across critical sectors.
#
# #### A. Healthcare: For a Billion-Strong Nation
# In a country with a challenging doctor-patient ratio, AI is a powerful force multiplier.
# *   **Case Study:** Startups like **Niramai** are using AI-powered thermal imaging for early, non-invasive breast cancer screening. In ophthalmology, **Aravind Eye Care System** uses Google's AI models to detect diabetic retinopathy, preventing blindness in thousands.
#
# #### B. Agriculture: Sowing the Seeds of the Future
# For the 60% of the population dependent on agriculture, AI is a game-changer.
# *   **Case Study:** Agritech platforms like **CropIn** use satellite imagery and AI to provide farmers with predictive insights on everything from soil health and pest control to crop yield estimates, boosting productivity and income.
#
# #### C. FinTech & Financial Inclusion
# AI is the backbone of India's FinTech revolution.
# *   **AI Solution:** Lenders are using AI algorithms to analyze alternative data points (like mobile phone usage) for credit scoring, bringing millions of unbanked individuals into the formal credit system. AI also works tirelessly behind the scenes to detect and prevent fraud on the massive UPI network.
#
# #### D. E-commerce & Retail
# In the hyper-competitive retail market, AI is the key to personalization.
# *   **AI Solution:** Giants like Flipkart and Myntra use sophisticated AI engines to understand user behaviour, provide hyper-personalized recommendations, and optimize their complex supply chains for lightning-fast delivery.
#
# #### E. Language & Inclusivity (The 'Bharat' Opportunity)
# How do you build for a nation with 22 official languages and hundreds of dialects?
# *   **AI Solution:** The government's **Bhashini project** is an ambitious mission to build Natural Language Processing (NLP) tools for Indian languages. This is enabling everything from real-time translation to voice-based services, ensuring that language is no longer a barrier to accessing the digital world.
#
# ***
#
# ### Navigating the Hurdles: The Reality Check for India's AI Ambition
#
# The road ahead is not without its challenges. To truly capitalize on its AI potential, India must address several critical issues:
#
# 1.  **The Infrastructure and Digital Divide:** While data is cheap, access to consistent, high-speed internet and the immense computational power required for advanced AI is still a luxury in many parts of the country.
# 2.  **Data Privacy and Security:** Building trust is paramount. The recent **Digital Personal Data Protection (DPDP) Act** is a crucial step, but its effective implementation will be key to ensuring that user data is handled ethically and securely.
# 3.  **Ethical AI and Algorithmic Bias:** If AI models are trained on biased historical data, they risk perpetuating and even amplifying existing social inequalities. Ensuring fairness and transparency in algorithms is a non-negotiable ethical imperative.
# 4.  **The Skilling Gap:** While the talent pool is vast, there is a significant gap between general STEM education and the specialized skills required for high-end AI/ML roles. A massive, nationwide upskilling effort is needed.
#
# ***
#
# ### The Road to 2030: What's Next for the Future of AI in India?
#
# *India's AI Endgame: From Follower to Leader*
#
# The next decade will be decisive. India is not content to be a mere consumer of AI technology; it aims to be a creator and a leader.
#
# *   **The Rise of Generative AI:** Indian companies are rapidly adopting **Generative AI**. Startups are building tools for everything from creating marketing content in regional languages to assisting developers in writing code, promising a massive leap in productivity.
# *   **India as a "Global AI Hub":** India has the potential to become the world's lab for "AI for Good," developing frugal, scalable, and impactful AI solutions for challenges in healthcare, agriculture, and education that can be exported to the developing world.
# *   **Sovereign AI Capabilities:** There is a strong push to build indigenous Large Language Models (LLMs) and sovereign compute infrastructure. This will reduce dependency on foreign tech and ensure that India's AI future is shaped by its own values and priorities.
#
# ***
#
# ### Conclusion: The Algorithm of a New India
#
# The **rise of AI in India** is more than just a technological trend; it's the algorithm of a new, self-reliant, and ambitious nation. Fueled by a unique combination of demographic, digital, and democratic strengths, India is scripting a unique AI story. The journey is complex and the challenges are real, but the code for a brighter, more inclusive future is being written today, in labs and farms, cities and villages, across the subcontinent. The 'Silicon Satta' has been placed, and the world is watching.
#
# ---
#
# **What do you think is the most exciting application of AI in India? Share your thoughts in the comments below!**
#
# *Follow us on [LinkedIn] and [Twitter] for more insights into India's incredible tech story.*
